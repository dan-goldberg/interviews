# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv('../data/fastballcommand.csv')

# %%
df.shape
# Out:
# (12481, 17)

# %%
df.describe()
# Out:
#              YearID  GamePitchSequence    PAofInning  AtBatPitchSequence  \
# count  12481.000000       12481.000000  12481.000000        12481.000000
# mean    2018.582886         102.192453      2.649547            2.820367
# std        0.646025          70.691196      1.509402            1.736469
# min     2018.000000           1.000000      1.000000            1.000000
# 25%     2018.000000          44.000000      1.000000            1.000000
# 50%     2018.000000          95.000000      2.000000            2.000000
# 75%     2019.000000         151.000000      3.000000            4.000000
# max     2020.000000         480.000000     11.000000           13.000000
#
#              Inning         Balls       Strikes      PitcherID      Velocity  \
# count  12481.000000  12481.000000  12481.000000   12481.000000  12474.000000
# mean       3.553001      0.892156      0.811634   19273.981892     92.400808
# std        2.126963      1.006264      0.817387   40739.593961      2.103674
# ...

# %%
df.sample(10)
# Out:
#        YearID                                GameID  GamePitchSequence  \
# 576      2018  52D490D6-B9E5-4FF7-91D6-07B836EDAA2E                116
# 2882     2019  46076794-E843-4CD2-9CD5-3C80EDCBC145                 47
# 770      2019  C446E8A8-FF10-4355-B13A-094EA7977522                  4
# 3873     2018  5E5AB994-61FF-43F0-A0BF-5C2F17DD4F9E                168
# 4447     2018  95DDBFE7-DF22-46A9-A7DC-64F01D0636C7                  2
# 8532     2018  171F2F83-9943-4179-9892-B1B2F1D8058B                 84
# 4807     2018  476006E9-6718-4147-A6AD-6937FD821A84                155
# 3876     2018  5E5AB994-61FF-43F0-A0BF-5C2F17DD4F9E                172
# 11816    2019  16A5ABE3-0A3C-47A5-8664-F3FFBDB38C0F                 27
# 1170     2020  B603E1A0-1668-45E0-96E5-0CB46F374CEC                200
#
#        PAofInning  AtBatPitchSequence  Inning  Balls  Strikes  PitcherID  \
# 576             1                   3       4      0        2       2779
# ...

# %%
sns.histplot(data=df, x='PlateLocHeight')
plt.title('PlateLocHeight')
plt.show()

# %%
sns.pairplot(data=df[
    [
        'Velocity',
        'VerticalBreak',
        'HorizontalBreak',
        'PlateLocHeight',
        'PlateLocSide',
        'PitchType'
    ]],
    hue="PitchType"
            )
plt.show()
